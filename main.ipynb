# %%
import pandas as pd

# %%
df_treino = pd.read_csv('AD_all_patients.csv')
df_teste = pd.read_csv('alzheimers_prediction_dataset.csv')

df_treino.head()
# Out:
#          Fp1       Fp2        F7        F3         Fz        F4        F8  \
# 0  116.99375  41.09375  66.69375 -64.50625 -126.40625   8.39375  22.49375
# 1  115.93125  38.63125  64.73125 -64.66875 -125.26875   8.73125  27.03125
# 2  115.72500  38.32500  66.02500 -62.67500 -135.37500   9.02500  29.42500
# 3  120.15625  40.75625  71.05625 -59.54375 -148.34375  12.15625  32.25625
# 4  119.50000  39.50000  71.30000 -59.20000 -125.50000  14.80000  28.50000
#
#          T3        C3        Cz       C4        T4         T5       P3  \
# 0  42.19375  53.29375   4.49375  2.49375  73.79375  129.29375  0.09375
# 1  43.23125  57.53125  11.13125  2.33125  72.23125  125.73125 -5.46875
# 2  47.12500  49.92500  24.42500  1.22500  72.92500  123.22500 -3.07500
# 3  49.05625  41.05625  12.75625  1.85625  73.55625  128.65625 -0.14375
# 4  48.80000  42.20000  -1.20000  1.40000  70.30000  116.10000  3.40000
#
#           Pz         P4  status
# 0 -124.90625 -245.50625       1
# ...

# %%
from pycaret.classification import *
print("PyCaret importado!")
# Out:
# PyCaret importado!

# %%
print(df_treino.columns.tolist())
# Out:
# ['Fp1', 'Fp2', 'F7', 'F3', 'Fz', 'F4', 'F8', 'T3', 'C3', 'Cz', 'C4', 'T4', 'T5', 'P3', 'Pz', 'P4', 'status']

# %%
plot_model(modelo_lr, plot='confusion_matrix')

# %%
modelo_lr = create_model('lr', fold=5)
# Out:
# <style type="text/css">
# #T_fdaf9_row5_col0, #T_fdaf9_row5_col1, #T_fdaf9_row5_col2, #T_fdaf9_row5_col3, #T_fdaf9_row5_col4, #T_fdaf9_row5_col5, #T_fdaf9_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_fdaf9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fdaf9_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_fdaf9_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_fdaf9_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_fdaf9_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_fdaf9_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_fdaf9_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_fdaf9_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
plot_model(modelo_lr, plot='confusion_matrix')

# %%
modelo_final = finalize_model(modelo_lr)

# %%
modelo_lgbm = create_model('lightgbm', fold=5)
# Out:
# <style type="text/css">
# #T_e5c6e_row5_col0, #T_e5c6e_row5_col1, #T_e5c6e_row5_col2, #T_e5c6e_row5_col3, #T_e5c6e_row5_col4, #T_e5c6e_row5_col5, #T_e5c6e_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_e5c6e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5c6e_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_e5c6e_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_e5c6e_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_e5c6e_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_e5c6e_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_e5c6e_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_e5c6e_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
plot_model(modelo_lgbm, plot='confusion_matrix')

# %%
modelo_nb = create_model('nb', fold=5)
# Out:
# <style type="text/css">
# #T_dbeca_row5_col0, #T_dbeca_row5_col1, #T_dbeca_row5_col2, #T_dbeca_row5_col3, #T_dbeca_row5_col4, #T_dbeca_row5_col5, #T_dbeca_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_dbeca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dbeca_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_dbeca_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_dbeca_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_dbeca_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_dbeca_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_dbeca_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_dbeca_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
plot_model(modelo_nb, plot='confusion_matrix')

# %%
modelo_rf = create_model('rf', fold=5)
# Out:
# <style type="text/css">
# #T_80288_row5_col0, #T_80288_row5_col1, #T_80288_row5_col2, #T_80288_row5_col3, #T_80288_row5_col4, #T_80288_row5_col5, #T_80288_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_80288">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80288_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_80288_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_80288_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_80288_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_80288_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_80288_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_80288_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
plot_model(modelo_rf, plot='confusion_matrix')

# %%
modelo_dt = create_model('dt', fold=5)
# Out:
# <style type="text/css">
# #T_b01f7_row5_col0, #T_b01f7_row5_col1, #T_b01f7_row5_col2, #T_b01f7_row5_col3, #T_b01f7_row5_col4, #T_b01f7_row5_col5, #T_b01f7_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_b01f7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b01f7_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_b01f7_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_b01f7_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_b01f7_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_b01f7_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_b01f7_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_b01f7_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
plot_model(modelo_dt, plot='confusion_matrix')

# %%
df_treino[df_treino['status'] == 1].head()
# Out:
#          Fp1       Fp2        F7        F3         Fz        F4        F8  \
# 0  116.99375  41.09375  66.69375 -64.50625 -126.40625   8.39375  22.49375
# 1  115.93125  38.63125  64.73125 -64.66875 -125.26875   8.73125  27.03125
# 2  115.72500  38.32500  66.02500 -62.67500 -135.37500   9.02500  29.42500
# 3  120.15625  40.75625  71.05625 -59.54375 -148.34375  12.15625  32.25625
# 4  119.50000  39.50000  71.30000 -59.20000 -125.50000  14.80000  28.50000
#
#          T3        C3        Cz       C4        T4         T5       P3  \
# 0  42.19375  53.29375   4.49375  2.49375  73.79375  129.29375  0.09375
# 1  43.23125  57.53125  11.13125  2.33125  72.23125  125.73125 -5.46875
# 2  47.12500  49.92500  24.42500  1.22500  72.92500  123.22500 -3.07500
# 3  49.05625  41.05625  12.75625  1.85625  73.55625  128.65625 -0.14375
# 4  48.80000  42.20000  -1.20000  1.40000  70.30000  116.10000  3.40000
#
#           Pz         P4  status
# 0 -124.90625 -245.50625       1
# ...

# %%
exp = setup(data=df_treino, target='status')
# Out:
# <style type="text/css">
# #T_87584_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_87584">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87584_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_87584_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87584_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_87584_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_87584_row0_col1" class="data row0 col1" >4282</td>
#     </tr>
#     <tr>
#       <th id="T_87584_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_87584_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_87584_row1_col1" class="data row1 col1" >status</td>
#     </tr>
#     <tr>
#       <th id="T_87584_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('AD_all_patients.csv')

mudancas_de_classe = np.sum(np.diff(df['status'].values) != 0)
print(f"Mudanças de classe: {mudancas_de_classe}")
# Out:
# Mudanças de classe: 17

# %%
import pandas as pd
from pycaret.classification import *

df = pd.read_csv('AD_all_patients.csv')

df['Subject_ID'] = (df.index // 13000).astype(str)

s = setup(
    data=df, 
    target='status', 
    fold_strategy='groupkfold', 
    fold_groups='Subject_ID',  
    fold=5,
    session_id=123,
    n_jobs=-1
)

modelos = compare_models(include=['rf', 'lightgbm', 'dt', 'lr', 'nb'])
# Out:
# <style type="text/css">
# #T_b26a7_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b26a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b26a7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b26a7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b26a7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b26a7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b26a7_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_b26a7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b26a7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b26a7_row1_col1" class="data row1 col1" >status</td>
#     </tr>
#     <tr>
#       <th id="T_b26a7_level0_row2" class="row_heading level0 row2" >2</th>
# ...
